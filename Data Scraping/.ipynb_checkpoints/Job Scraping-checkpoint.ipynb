# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re
import time

# %% [markdown]
# # Get jobs

# %%
source = requests.get('https://th.jobsdb.com/th').text
soup = BeautifulSoup(source,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html prefix="og: http://ogp.me/ns#">
#  <head>
#   <title>
#    Job search, job opportunities &amp; career development | jobsDB Thailand
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"e08d188211","applicationID":"27673588","transactionName":"blUGNUdSXhVWWkBZC1cfKTd2HHgJWlx3XwpNQgsNWVZCSX5XUFUc","queueTime":0,"applicationTime":282,"agent":"","atts":""}
#   </script>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"VwYAVVBRGwEHUlZRAgkP",licenseKey:"e08d188211",applicationID:"27673588"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(21),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(22),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),c.xhrWrappable&&t(10),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(9),s=t(8),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof x&&(this.bstStart=y.now())}),o.on(w,function(t,n){var e=t[0];e instanceof x&&i("bst",[e,n,this.bstStart,y.now()])}),a.on(m,function(t,n,e){this.bstStart=y.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,y.now(),this.bstType])}),s.on(m,function(){this.bstStart=y.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,y.now(),"requestAnimationFrame"])}),o.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),o.on(g+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t("wrap-function")(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start", ...
#   </script>
#   <!-- Meta start -->
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/Images/shared/v8revamp2/favicon.ico" rel="SHORTCUT ICON"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="jobsDB is the largest Recruitment Network across Asia Pacific - Australia, China, Hong Kong, India, Indonesia, Korea, Malaysia, Philippines, Singapore, Thailand, Taiwan &amp; USA. Offering job search and posting, career tips and human resources solution to job seekers, corporate employers &amp; recruiters." name="description"/>
#   <meta content="job jobs" name="keywords"/>
#   <meta content="Job search, job opportunities &amp; career development | jobsDB Thailand" name="og:title"/>
#   <meta content="jobsDB is the largest Recruitment Network across Asia Pacific - Australia, China, Hong Kong, India, Indonesia, Korea, Malaysia, Philippines, Singapore, Thailand, Taiwan &amp; USA. Offering job search and posting, career tips and human resources solution to job seekers, corporate employers &amp; recruiters." name="og:description"/>
#   <meta content="https://th.content.jobsdbcdn.com/Content/v381/Images/shared/og_image_1200x1200.png" name="og:image"/>
#   <meta content="https://th.jobsdb.com/th" name="og:url"/>
#   <meta content="website" name="og:type"/>
#   <link href="https://th.jobsdb.com/th" rel="canonical"/>
#   <link href="https://m.jobsdb.co.th/en-th/search.do" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="https://m.jobsdb.co.th/en-th/search.do" media="handheld" rel="alternate"/>
#   <link href="https://th.jobsdb.com/th" hreflang="en-th" rel="alternate"/>
#   <link href="https://th.jobsdb.com/th/th" hreflang="th-th" rel="alternate"/>
#   <!-- Meta end -->
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minJs_Revamp2_reset.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minJs_Revamp2_global.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minHeader_desk.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minEffect.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minJs_Revamp2_mod_home.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minJs_Revamp2_searchbox.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Muli:400,400i,600,600i,700,700i" rel="stylesheet"/>
#   <!-- Global site tag (gtag.js) - Google Ads -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-944810267">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-944810267');
#   gtag('config', 'AW-876104264');
#   </script>
#   <!-- /Global site tag (gtag.js) - Google Ads -->
#   <script type="text/javascript">
#    //<![CDATA[
#     var debugMode = false;
#     window.jobsDB = {};
#
#     // Path related variables
#     var virtualDir = '/TH/EN/';
#     var javascriptUrlBase = 'https://th.content.jobsdbcdn.com/Content/v381/Javascript/';
#     var javascriptUrlBaseList = ["https://th.content.jobsdbcdn.com/Content/v381/Javascript/"];
#     var cssUrlBase = 'https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/';
#     var imagesUrlBase = 'https://th.content.jobsdbcdn.com/Content/v381/Images/';
#     var attachmentUrlBase = ["","th","Content","v381","Temp",""].join('/');
#     var g_currentSite = 'https://th.jobsdb.com/TH/en';
#     var g_dotComDomain = 'th.jobsdb.com';
#     var g_analysisDomain = 'analysis.jobsdb.co.th';
#     var g_countryCode = 'TH';
#     var g_languageCode = 'EN';
#     var g_local_CSHotline = "(662)667 0824 and (662)667 0700";
#     var g_local_Email = "CS@jobsDB.co.th";
#
#     //TODO: this is not a real serverTime, however server side validation should catch if input date is invalid (such as out of bound)
#     var serverTime = new Date();
#
#     var jsLoginFlag = false;
#     var empLoginFlag = false;
#
#     // get Employer Ticket and ID
#     var getAuthenEmpTicketKey = 'EMP_authenTicket';
#     var getAuthenEmpAccountInfoKey = 'EmpAccInfo';
#
#     // get JobSeeker Ticket and ID
#     var getAuthenJsTicketKey = 'JS_authenTicket_XX';
#     var getAuthenUserJsIdKey = 'JS_authenUserId';
#     var getAuthenJsAccountInfoKey = 'JsAccInfo_XX';
#
#     // User Name
#     var userName;
#
#     // Form framework related variables
#     var loadedJsList= ["JobsDB.combined.min.js","JobsDB.form.min.js","JobsDB_System_ControllerResponseConversion.js"];
#     var isPageLoaded = false; // Set to true in $(document).ready()
#     var pageOnLoadActionList = new Array(); // Dispatched in $(document).ready()
#
#     var commonBodyStartConfirmation = "Confirmation";
#     var ajaxErrorMessage = "Try again later please!";
#
#
#
#     var jsLoginControllerResponse = {"Type":0,"CountryCode":"","LanguageCode":"","Webflow":6,"ActionUrl":"","WebflowAction":2,"JsonData":"","JsonNotificationData":null,"JsonErrorData":null,"Description":"No Description.","EvalScript":null,"NextControllerResponeseDelayTime":0,"NextControllerResponese":"{\"Type\":0,\"CountryCode\":\"\",\"LanguageCode\":\"\",\"Webflow\":0,\"ActionUrl\":null,\"WebflowAction\":0,\"JsonData\":null,\"JsonNotificationData\":null,\"JsonErrorData\":null,\"Description\":\"No Description.\",\"EvalScript\":\"JobsDB_System_Messaging.PublishEvent%28%27Login.SetupSource%27%2C%20%22Others%22%2C%20%27local%27%29%3B\",\"NextControllerResponeseDelayTime\":0,\"NextControllerResponese\":null,\"IsBlocked\":false,\"Target\":0,\"UnBlockingEvent\":0,\"ContainerWidth\":-1,\"ContainerHeight\":-1,\"IsAlwaysPost\":false,\"IsNormalMemberFristLogin\":false,\"Code\":0}","IsBlocked":false,"Target":0,"UnBlockingEvent":0,"ContainerWidth":-1,"ContainerHeight":-1,"IsAlwaysPost":false,"IsNormalMemberFristLogin":false,"Code":0}
#     jsLoginControllerResponse.ActionUrl = [null,'Login','RevampedLoginBoxForJobSeeker'].join('/');
#
#     var jsLoginForFullAccessControllerResponse = {"Type":0,"CountryCode":"","LanguageCode":"","Webflow":6,"ActionUrl":"","WebflowAction":2,"JsonData":"","JsonNotificationData":null,"JsonErrorData":null,"Description":"No Description.","EvalScript":null,"NextControllerResponeseDelayTime":0,"NextControllerResponese":"{\"Type\":0,\"CountryCode\":\"\",\"LanguageCode\":\"\",\"Webflow\":0,\"ActionUrl\":null,\"WebflowAction\":0,\"JsonData\":null,\"JsonNotificationData\":null,\"JsonErrorData\":null,\"Description\":\"No Description.\",\"EvalScript\":\"JobsDB_System_Messaging.PublishEvent%28%27Login.SetupSource%27%2C%20%22Others%22%2C%20%27local%27%29%3B\",\"NextControllerResponeseDelayTime\":0,\"NextControllerResponese\":null,\"IsBlocked\":false,\"Target\":0,\"UnBlockingEvent\":0,\"ContainerWidth\":-1,\"ContainerHeight\":-1,\"IsAlwaysPost\":false,\"IsNormalMemberFristLogin\":false,\"Code\":0}","IsBlocked":false,"Target":0,"UnBlockingEvent":0,"ContainerWidth":-1,"ContainerHeight":-1,"IsAlwaysPost":false,"IsNormalMemberFristLogin":false,"Code":0}
#     jsLoginForFullAccessControllerResponse.ActionUrl = [null,'Login','LoginForFullAccessLoginBox'].join('/');
#
#     var empLoginControllerResponse = {"Type":0,"CountryCode":"","LanguageCode":"","Webflow":0,"ActionUrl":"","WebflowAction":2,"JsonData":"Employer","JsonNotificationData":null,"JsonErrorData":null,"Description":"No Description.","EvalScript":null,"NextControllerResponeseDelayTime":0,"NextControllerResponese":null,"IsBlocked":false,"Target":0,"UnBlockingEvent":0,"ContainerWidth":-1,"ContainerHeight":-1,"IsAlwaysPost":false,"IsNormalMemberFristLogin":false,"Code":0}
#     empLoginControllerResponse.ActionUrl = [null,'Login','EmployerLogin'].join('/');
#
#     var webflow_fallbackToCountry = "";
#
#     var isInRevampedPage = true;
#     var currentWebFlowName = "MainPage";
#
#  //]]>
#   </script>
#   <script type="text/javascript">
#    var IsInPopupPage = false;
#         var IsIframe = false;
#   </script>
#   <!--[if lte IE 8]>
# <script src="https://th.content.jobsdbcdn.com/Content/v381/Javascript/html5fix.min.js"></script>
# <![endif]-->
#   <!--[if IE]>
# <link href="https://th.content.jobsdbcdn.com/Content/v381/SSL/Css/minIExplorer.css" rel="stylesheet" type="text/css" media="all" />
#
# <![endif]-->
#  </head>
#  <body class="jobseeker-site db16 country-th lang-en mod-home home-index home-sherlock has-hero">
#   <script type="text/javascript">
#    var s_contextData = [];
#   </script>
#   <!-- #BeginEditable "P1HomepagePromotionBanner - Banner Old" -->
#   <!-- #EndEditable -->
#   <header class="db16-header navbar navbar-default-candi" data-bootstrap="false" id="js-site-header" role="banner">
#    <div class="container">
#     <div class="navbar-header">
#      <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#main-nav" data-toggle="collapse" type="button">
#       <span class="sr-only">
#       </span>
#       <strong>
#        ☰
#       </strong>
#       Menu
#      </button>
#      <a class="navbar-brand-logo navbar-brand-logo-2015" href="https://th.jobsdb.com/th">
#       jobsDB
#      </a>
#     </div>
#     <nav class="collapse navbar-collapse" id="main-nav">
#      <ul class="nav navbar-nav navbar-switchers">
#       <li class="dropdown dropdown-country">
#        <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#         <span class="flag-icon flag-icon-th">
#         </span>
#         <span class="flag-label">
#          Thailand
#         </span>
#         <span class="caret">
#         </span>
#        </a>
#        <ul aria-labelledby="countries" class="dropdown-menu multi-level dropdown-menu-fancy with-header">
#         <li>
#          Change Country
#         </li>
#         <li class="">
#          <a data-country="HK" href="https://hk.jobsdb.com/hk">
#           <span class="flag-icon flag-icon-hk">
#           </span>
#           Hong Kong
#          </a>
#         </li>
#         <li class="">
#          <a data-country="ID" href="https://id.jobsdb.com/id">
#           <span class="flag-icon flag-icon-id">
#           </span>
#           Indonesia
#          </a>
#         </li>
#         <li class="">
#          <a data-country="SG" href="https://sg.jobsdb.com/sg">
#           <span class="flag-icon flag-icon-sg">
#           </span>
#           Singapore
#          </a>
#         </li>
#         <li class="active">
#          <a data-country="TH" href="https://th.jobsdb.com/th">
#           <span class="flag-icon flag-icon-th">
#           </span>
#           Thailand
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="switch-language active">
#        <a class="navbar-link" href="https://th.jobsdb.com/th" onclick="$.cookie('DefaultLang', 'en',{ path:'/', expires: 3650});$.cookie('AcknowledgedLangSwitcher','AcknowledgedLangSwitcher',{ path:'/', expires: 3650});">
#         English
#        </a>
#       </li>
#       <li class="switch-language">
#        <a class="navbar-link" href="https://th.jobsdb.com/th/th" onclick="$.cookie('DefaultLang', 'th',{ path:'/', expires: 3650});$.cookie('AcknowledgedLangSwitcher','AcknowledgedLangSwitcher',{ path:'/', expires: 3650});">
#         ภาษาไทย
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right navbar-anonymous">
#       <li class="dropdown-menu-download-app">
#        <a class="appDownloadLink">
#         Download app
#        </a>
#       </li>
#       <li class="dropdown-menu-search">
#        <a href="https://th.jobsdb.com/th">
#         Search for jobs
#        </a>
#       </li>
#       <li class="dropdown-menu-resources">
#        <a href="/en-th/career-recruitment-advice/">
#         Resources
#        </a>
#       </li>
#       <li class="dropdown-menu-login">
#        <a class="navbar-link" href="https://th.jobsdb.com/th/en/login/jobseekerlogin" id="Head_Login">
#         Log in
#        </a>
#       </li>
#       <li class="dropdown-menu-create-profile">
#        <a class="btn btn-cta" href="https://th.jobsdb.com/th/en/jobseeker/registration" id="JobSeekerRegistrationLink">
#         Sign up
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right navbar-universal-login">
#       <li>
#        <a class="btn btn-default fn-header-emplogin" href="https://th.jobsdb.com/th/en/home/employerindex">
#         Employer site
#        </a>
#        <a class="btn btn-primary fn-header-canlogin" href="https://th.jobsdb.com/th/en/login/jobseekerlogin">
#         Log in
#        </a>
#        <a class="btn btn-primary fn-header-canreg" href="https://th.jobsdb.com/th/en/jobseeker/registration">
#         Sign up
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right navbar-user">
#       <li class="dropdown dropdown-owner">
#        <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle profile-owner-container" data-toggle="dropdown" href="#" role="button">
#         <span class="profile-owner invitation-indicator">
#          <strong id="label_SSOUserName">
#          </strong>
#          <small class="text-muted JSLatestJobTitle">
#          </small>
#         </span>
#         <span class="caret">
#         </span>
#        </a>
#        <ul class="dropdown-menu">
#         <li class="dropdown-menu-profile profile-in hidden-xs">
#          <a href="https://th.jobsdb.com/th/en/MyJobsDB/profile">
#           <ins class="icon-profile">
#           </ins>
#           View profile
#          </a>
#         </li>
#         <li class="dropdown-menu-invitation profile-in hidden-xs">
#          <a class="JsInvitationCount" data-has-invitation="{0} Job Invitations" data-template="&lt;ins class='icon-invitation invitation-indicator'&gt;&lt;/ins&gt;" data-when-empty="No job invitations" href="https://th.jobsdb.com/th/en/Invitations/InvitationList">
#          </a>
#         </li>
#         <li class="dropdown-menu-myjobsdb profile-in hidden-xs">
#          <a href="https://th.jobsdb.com/th/en/MyJobsDB">
#           <ins class="icon-myjobsdb">
#           </ins>
#           My jobsDB
#          </a>
#         </li>
#         <li class="dropdown-menu-download-app">
#          <a class="appDownloadLink">
#           Download app
#          </a>
#         </li>
#         <li class="dropdown-menu-search">
#          <a href="https://th.jobsdb.com/th">
#           Search for jobs
#          </a>
#         </li>
#         <li class="dropdown-menu-resources">
#          <a href="/en-th/career-recruitment-advice/">
#           Resources
#          </a>
#         </li>
#         <li class="dropdown-menu-login profile-out">
#          <a href="https://th.jobsdb.com/th/en/login/jobseekerlogin" title="Login">
#           Log in
#          </a>
#         </li>
#         <li class="dropdown-menu-logout profile-in">
#          <a href="javascript:;" id="HeaderLogOffLink" title="Logout">
#           Log out
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </nav>
#    </div>
#    <script type="text/javascript">
#     try {
#             (function(){
#                 if (document.cookie && document.cookie != '' && document.cookie.indexOf(getAuthenJsAccountInfoKey) > -1) {
#                     var cookies = document.cookie.substring(document.cookie.indexOf(getAuthenJsAccountInfoKey)).split(';')
#                     var user = cookies[0].split('=');
#                     var userObj = JSON.parse(decodeURIComponent(user[1]));
#                     document.querySelector("#label_SSOUserName").innerHTML = userObj.Name;
#                     document.querySelector("body").className += " logged-in";
#                     var title = localStorage.getItem('JsLatestPosition');
#                     if (title && title.length > 0) {
#                         document.querySelector("#js-site-header .JSLatestJobTitle").innerHTML = title;
#                     }
#                 }
#                 else
#                 {
#                     document.querySelector("body").className += " logged-out";
#                 }
#             })();
#         }
#         catch (e) { console.log(e);  }
#    </script>
#   </header>
#   <style type="text/css">
#    .n-none > a {background-position: -20px -20px !important;}
#   </style>
#   <div class="menu db16-menu hidden-xs">
#    <div class="container">
#     <nav class="navbar navbar-default" id="topmenu" role="navigation">
#      <div class="navbar-header">
#       <button aria-expanded="false" class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#        <span class="sr-only">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <span class="n-home active">
#        <a class="navbar-brand" href="https://th.jobsdb.com/th" onclick='return TriggerSetWindowLocation("https://th.jobsdb.com/th");' title="Home">
#         Home
#        </a>
#       </span>
#      </div>
#      <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#       <ul class="nav navbar-nav candi">
#        <li class="n-myjobsdb">
#         <a href="https://th.jobsdb.com/th/en/MyJobsDB" onclick='window.location="https://th.jobsdb.com/th/en/MyJobsDB";return false;' title="My jobsDB">
#          My jobsDB
#         </a>
#        </li>
#        <li class="n-resources">
#         <a href="/en-th/career-recruitment-advice/" onclick='window.location="/en-th/career-recruitment-advice/";return false;' title="Resources">
#          Resources
#         </a>
#        </li>
#        <li class="n-campus">
#         <a href="https://th.jobsdb.com/th-th/pages/jobsdb-campnet" onclick='window.location="https://th.jobsdb.com/th-th/pages/jobsdb-campnet";return false;' title="CampNet">
#          CampNet
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <!-- #BeginEditable "Banner A and Banner B" -->
#   <!-- #BeginEditable "Hero Area" -->
#   <div class="hero-area" id="hero-area" style="display: none">
#    <div class="content-page ext" style="background: url(https://d1z2n4lojgccee.cloudfront.net/LANDING_BANNER_1.jpg) 50% 10% no-repeat; background-size: auto;">
#     <div class="content01">
#     </div>
#    </div>
#   </div>
#   <!-- #EndEditable -->
#   <div class="page-body">
#    <div class="content-page">
#     <div class="page-content">
#      <!-- #BeginEditable "SearchBox Old" or "SearchBox New" -->
#      <section class="home-primary sherlock-searchbar sherlock-searchbar-hero">
#       <div class="sherlock-search-action">
#        <div class="search-from-default-toggler">
#         <a class="toggle-more" id="searchbox-expand">
#          More options
#         </a>
#         <a class="toggle-fewer" id="searchbox-collapse">
#          Fewer options
#         </a>
#        </div>
#        <div class="sherlock-search-go">
#         <a class="sherlock-search-button button button-dull" id="searchbox-submit">
#          Search
#         </a>
#        </div>
#       </div>
#       <hgroup>
#        <h1 class="searchbar-headline">
#         Search
#         <span class="searchbar-total-job-count">
#          9,900
#         </span>
#         jobs
#        </h1>
#        <a class="searchbar-learn-more" onclick="LearnMore()">
#         <ins>
#          Learn more
#         </ins>
#        </a>
#       </hgroup>
#       <div class="sherlock-form-container" id="searchbox-container">
#        <div class="sherlock-search-form">
#         <div class="search-form-default">
#          <div class="search-form-body">
#           <fieldset class="search-form-row row-1" id="searchbox-keyfieldset">
#            <div class="search-cell search-for-keywords options-appended" id="keywordContainer">
#             <label class="label-keywords">
#              Keywords
#             </label>
#             <div class="input-group input-group-text-cross">
#              <input id="keywordInput" name="keywordInput" type="text"/>
#              <a class="input-element input-element-cross" id="keywordClear">
#               <span>
#                ×
#               </span>
#              </a>
#              <div class="append-option">
#               <a class="append-option-trigger" id="searchTypeFilter">
#                <span>
#                 Options
#                </span>
#                <ins>
#                </ins>
#               </a>
#              </div>
#              <div class="sherlock-extralayer" id="KeywordSuggestsContainer">
#               <div class="input-groupex">
#                <div class="input-groupex-cat sherlock-no-suggestions" id="NoSuggestionMsg">
#                 <p class="groupex-empty">
#                  No matching results found. Try different keywords?
#                 </p>
#                </div>
#                <div class="input-groupex-cat sherlock-keywords-recent" id="RecentSuggestContainer">
#                </div>
#                <div class="input-groupex-cat sherlock-keywords-pos" id="JobTitleSuggestContainer">
#                </div>
#                <div class="input-groupex-cat sherlock-keywords-emp" id="CompanySuggestContainer">
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="search-cell search-for-location" id="searchbox-location-select">
#             <div class="pillow-group input-group-text-arrow-south">
#              <a class="pillow-element pillow-element-arrow-south">
#               <span class="pillow-txt-mask">
#                <var class="pillow-txt">
#                </var>
#               </span>
#               <ins>
#               </ins>
#              </a>
#              <div class="pillow-fader hide">
#               <span>
#                … +
#                <var class="pillow-count">
#                </var>
#                more
#               </span>
#              </div>
#             </div>
#            </div>
#            <input id="searchbox-location" type="hidden"/>
#           </fieldset>
#           <fieldset class="search-form-row row-2" id="searchbox-row2fieldset">
#            <div class="search-cell search-for-jobfunction" id="searchbox-jfunc-select">
#             <div class="pillow-group input-group-text-arrow-south">
#              <a class="pillow-element pillow-element-arrow-south">
#               <span class="pillow-txt-mask">
#                <var class="pillow-txt">
#                </var>
#               </span>
#               <ins>
#               </ins>
#              </a>
#              <div class="pillow-fader hide">
#               <span>
#                … +
#                <var class="pillow-count">
#                </var>
#                more
#               </span>
#              </div>
#             </div>
#            </div>
#            <input id="searchbox-jfunc" type="hidden"/>
#            <div class="search-cell search-for-salary" id="searchbox-salary-select">
#             <label>
#              Salary
#             </label>
#             <div class="combined-group">
#              <menu class="combined-group-body">
#               <li class="combined-gp-item combined-gp-dropdn search-salary-currency">
#                <a class="sselect-trigger" id="searchbox-salaryType-select">
#                 <span>
#                 </span>
#                </a>
#               </li>
#               <li class="combined-gp-item combined-gp-dropdn search-salary-band search-salary-from">
#                <a class="sselect-trigger" id="searchbox-salaryFrom-select">
#                 <em class="salary-currency">
#                  THB
#                 </em>
#                 <span>
#                 </span>
#                </a>
#               </li>
#               <li class="combined-gp-item combined-gp-text">
#                <em>
#                 to
#                </em>
#               </li>
#               <li class="combined-gp-item combined-gp-dropdn search-salary-band search-salary-to">
#                <a class="sselect-trigger" id="searchbox-salaryTo-select">
#                 <span>
#                 </span>
#                </a>
#               </li>
#              </menu>
#             </div>
#            </div>
#            <input id="searchbox-salaryType" type="hidden"/>
#            <input id="searchbox-salaryFrom" type="hidden"/>
#            <input id="searchbox-salaryTo" type="hidden"/>
#           </fieldset>
#           <!-- /defaults -->
#          </div>
#         </div>
#         <!-- extras -->
#         <div class="search-form-extended hide" id="searchbox-extended" style="">
#          <fieldset class="search-form-row row-3" id="searchbox-row3fieldset">
#           <div class="search-cell search-for-career" id="searchbox-career-select">
#            <div class="pillow-group input-group-text-arrow-south">
#             <a class="pillow-element pillow-element-arrow-south">
#              <span class="pillow-txt-mask">
#               <var class="pillow-txt">
#               </var>
#              </span>
#              <ins>
#              </ins>
#             </a>
#             <div class="pillow-fader hide">
#              <span>
#               … +
#               <var class="pillow-count">
#               </var>
#               more
#              </span>
#             </div>
#            </div>
#           </div>
#           <input id="searchbox-career" type="hidden"/>
#           <div class="search-cell search-for-emptype" id="searchbox-empterm-select">
#            <div class="pillow-group input-group-text-arrow-south">
#             <a class="pillow-element pillow-element-arrow-south">
#              <span class="pillow-txt-mask">
#               <var class="pillow-txt">
#               </var>
#              </span>
#              <ins>
#              </ins>
#             </a>
#             <div class="pillow-fader hide">
#              <span>
#               … +
#               <var class="pillow-count">
#               </var>
#               more
#              </span>
#             </div>
#            </div>
#           </div>
#           <input id="searchbox-empterm" type="hidden"/>
#           <div class="search-cell search-for-education" id="searchbox-qualification-select">
#            <div class="pillow-group input-group-text-arrow-south">
#             <a class="pillow-element pillow-element-arrow-south">
#              <span class="pillow-txt-mask">
#               <var class="pillow-txt">
#               </var>
#              </span>
#              <ins>
#              </ins>
#             </a>
#             <div class="pillow-fader hide">
#              <span>
#               … +
#               <var class="pillow-count">
#               </var>
#               more
#              </span>
#             </div>
#            </div>
#           </div>
#           <input id="searchbox-qualification" type="hidden"/>
#          </fieldset>
#         </div>
#         <!-- /extras -->
#        </div>
#       </div>
#       <div id="InvalidSearchCriteriaLayer" style="display:none">
#        <div class="layer-content layer-search-box-empty no-cross no-ribbon">
#         <div class="layer-header">
#         </div>
#         <div class="layer-title">
#          <h4>
#           Search Jobs
#          </h4>
#         </div>
#         <div class="layer-body">
#          <div class="search-box-empty">
#           <ins class="layer-icon icon-alert">
#           </ins>
#           <p class="msg">
#            Enter keywords, or select a job function or a job location to start the search.
#           </p>
#           <div class="button-set">
#            <a class="button button-dull" href="#" id="InvalidSearchCriteriaLayerOkButton">
#             OK
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="sherlock-promotebox">
#        <div class="home-myprofile-static">
#         <div class="home-myprofile-item myprofile-jobalert">
#          <a href="https://th.jobsdb.com/TH/en/JobAlert/JobAlertCreation" id="linkJobAlert">
#           <h5 id="TotalJobAlert">
#            No Job Alerts
#           </h5>
#           <h6 id="MessageJobAlert">
#            Get new jobs delivered to your mailbox
#           </h6>
#          </a>
#          <div id="PromoBalloonAttachPoint">
#          </div>
#         </div>
#         <div class="home-myprofile-item myprofile-resume">
#          <a href="https://th.jobsdb.com/TH/en/Resumes/ResumeIndex" id="linkResumeRequest">
#           <h5 id="headerResumeRequest">
#            Create Resume
#           </h5>
#           <h6 id="letEmployerLabel">
#            Let employers find your profile
#           </h6>
#          </a>
#         </div>
#        </div>
#       </div>
#      </section>
#      <!-- #EndEditable -->
#      <section class="home-secondary">
#       <section class="home-main">
#        <div class="clearboth" style="margin: -10px 0 10px 5px">
#         <!--<script src="http://adelivery.th.jobsdb.com/jobsdb-id/view?zone=Premium_Center&zoneid=25"></script>-->
#         <script src="https://th.jobsdb.com/delivery/ajs.php?zoneid=25" type="text/javascript">
#         </script>
#        </div>
#        <div class="home-personlized">
#         <div class="home-personlized-cnt">
#          <div class="home-personlized-nav">
#           <nav class="personalized-nav personalized-nav-main">
#            <menu class="personalized-nav-menu">
#             <li class="personalized-nav-li" id="MyJobAlertLink">
#              <a>
#               <span>
#                Job Alert
#               </span>
#              </a>
#             </li>
#             <li class="personalized-nav-li focusing" id="BrowseJobLink">
#              <a>
#               <span>
#                Browse jobs
#               </span>
#              </a>
#             </li>
#            </menu>
#           </nav>
#          </div>
#          <div class="home-personlized-body">
#           <div class="personlized-body personalized-body-browsejob home-browse-job2" id="BrowseJobWrap">
#            <div class="home-browse-job" id="browsejob">
#             <div class="browse-job-head section-head">
#              <h2 class="section-head-title">
#               <a href="https://th.jobsdb.com/th/en/browse">
#                View all
#               </a>
#              </h2>
#              <div class="browse-job-tabgp">
#               <menu>
#                <li class="browse-job-tab function current" id="jobBrowserTabButton0">
#                 <a>
#                  Function
#                 </a>
#                </li>
#                <li class="browse-job-tab industry" id="jobBrowserTabButton1">
#                 <a>
#                  Industry
#                 </a>
#                </li>
#                <li class="browse-job-tab location" id="jobBrowserTabButton2">
#                 <a>
#                  Location
#                 </a>
#                </li>
#               </menu>
#              </div>
#             </div>
#             <div>
#              <div class="browse-job-body section-body" id="jobBrowserTabBody0">
#               <div>
#                <menu class="browse-job-body-menu">
#                 <li class="browse-job-category">
#                  <div class="job-category-wrapper">
#                   <a class="joblistinglink" href="/th/jobs/accounting/1?JSSRC=HPJC">
#                    <span class="job-category-title">
#                     <span>
#                      Accounting
#                     </span>
#                    </span>
#                   </a>
#                   <small>
#                    (1070)
#                   </small>
#                  </div>
#                  <div class="balloonWrapper hide">
#                   <div class="category">
#                    <div class="jobBrowserLayer clearfix">
#                     <div class="layerContainer clearfix">
#                      <div class="header clearfix">
#                       <h3>
#                        <a href="/th/jobs/accounting/1?JSSRC=HPJC">
#                         Accounting
#                        </a>
#                       </h3>
#                       <div class="clearfix hideLayer">
#                        <a>
#                         <span>
#                          ✕
#                         </span>
#                        </a>
#                       </div>
#                      </div>
#                      <div class="body clearfix">
#                       <div class="lv2cats clearfix">
#                        <menu class="first">
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/accounting/audit/1?JSSRC=HPJC" title="Audit">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Audit
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (228)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/accounting/credit-control/1?JSSRC=HPJC" title="Credit Control">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Credit Control
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (168)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/accounting/general-accounting/1?JSSRC=HPJC" title="General Accounting">
#                            <span class="namewrap clearfix">
#                             <span>
#                              General Accounting
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (823)
#                           </small>
#                          </div>
#                         </li>
#                        </menu>
#                        <menu>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/accounting/taxation/1?JSSRC=HPJC" title="Taxation">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Taxation
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (362)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/accounting/others/1?JSSRC=HPJC" title="Others">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Others
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (436)
#                           </small>
#                          </div>
#                         </li>
#                        </menu>
#                       </div>
#                       <div class="allJobs clearfix">
#                        <p>
#                         <a href="/th/jobs/accounting/1?JSSRC=HPJC">
#                          <span>
#                           View all &gt;&gt;
#                          </span>
#                         </a>
#                        </p>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </li>
#                 <li class="browse-job-category">
#                  <div class="job-category-wrapper">
#                   <a class="joblistinglink" href="/th/jobs/admin-hr/1?JSSRC=HPJC">
#                    <span class="job-category-title">
#                     <span>
#                      Admin &amp; HR
#                     </span>
#                    </span>
#                   </a>
#                   <small>
#                    (943)
#                   </small>
#                  </div>
#                  <div class="balloonWrapper hide">
#                   <div class="category">
#                    <div class="jobBrowserLayer clearfix">
#                     <div class="layerContainer clearfix">
#                      <div class="header clearfix">
#                       <h3>
#                        <a href="/th/jobs/admin-hr/1?JSSRC=HPJC">
#                         Admin &amp; HR
#                        </a>
#                       </h3>
#                       <div class="clearfix hideLayer">
#                        <a>
#                         <span>
#                          ✕
#                         </span>
#                        </a>
#                       </div>
#                      </div>
#                      <div class="body clearfix">
#                       <div class="lv2cats clearfix">
#                        <menu class="first">
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/administration-operation-clerical-support/1?JSSRC=HPJC" title="Administration / Operation / Clerical Support">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Administration / Operation / Clerical Support
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (479)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/compensation-benefits/1?JSSRC=HPJC" title="Compensation &amp; Benefits">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Compensation &amp; Benefits
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (224)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/employee-relations/1?JSSRC=HPJC" title="Employee Relations">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Employee Relations
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (198)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/recruitment-executive-search/1?JSSRC=HPJC" title="Recruitment / Executive Search">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Recruitment / Executive Search
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (195)
#                           </small>
#                          </div>
#                         </li>
#                        </menu>
#                        <menu>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/secretary-personal-assistant/1?JSSRC=HPJC" title="Secretary / Personal Assistant">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Secretary / Personal Assistant
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (124)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/training-development/1?JSSRC=HPJC" title="Training &amp; Development">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Training &amp; Development
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (203)
#                           </small>
#                          </div>
#                         </li>
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/admin-hr/others/1?JSSRC=HPJC" title="Others">
#                            <span class="namewrap clearfix">
#                             <span>
#                              Others
#                             </span>
#                            </span>
#                           </a>
#                           <small>
#                            (243)
#                           </small>
#                          </div>
#                         </li>
#                        </menu>
#                       </div>
#                       <div class="allJobs clearfix">
#                        <p>
#                         <a href="/th/jobs/admin-hr/1?JSSRC=HPJC">
#                          <span>
#                           View all &gt;&gt;
#                          </span>
#                         </a>
#                        </p>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </li>
#                 <li class="browse-job-category">
#                  <div class="job-category-wrapper">
#                   <a class="joblistinglink" href="/th/jobs/banking-finance/1?JSSRC=HPJC">
#                    <span class="job-category-title">
#                     <span>
#                      Banking / Finance
#                     </span>
#                    </span>
#                   </a>
#                   <small>
#                    (749)
#                   </small>
#                  </div>
#                  <div class="balloonWrapper hide">
#                   <div class="category">
#                    <div class="jobBrowserLayer clearfix">
#                     <div class="layerContainer clearfix">
#                      <div class="header clearfix">
#                       <h3>
#                        <a href="/th/jobs/banking-finance/1?JSSRC=HPJC">
#                         Banking / Finance
#                        </a>
#                       </h3>
#                       <div class="clearfix hideLayer">
#                        <a>
#                         <span>
#                          ✕
#                         </span>
#                        </a>
#                       </div>
#                      </div>
#                      <div class="body clearfix">
#                       <div class="lv2cats clearfix">
#                        <menu class="first">
#                         <li>
#                          <div class="innerpane clearfix">
#                           <a class="clearfix" href="/th/job-list/banking-finance/analysis/1?JSSRC=HPJC" title="Analysis">
# ...
# var utcOffsetMins = 420;
# s.eVar32 = GetCurrentDateTimeTrackingValue(utcOffsetMins);
# if(s.getQueryParam('utm_content') != '') {
# s.contextData['utm_content'] = s.getQueryParam('utm_content');
# }
# if(s.getQueryParam('EditMonthDiff') != '') {
# s.contextData['JobAlert.EditMonthDiff'] = s.getQueryParam('EditMonthDiff');
# }
# s.contextData['Page.LoadTime'] = s_getLoadTime();
# if(s_contextData && Object.prototype.toString.call( s_contextData ) === '[object Array]'){
# for(var i=0;i<s_contextData.length;i++){
# s.contextData[s_contextData[i][0]] = s_contextData[i][1];
# }
# }
# if(typeof JobsDB_Common != 'undefined' && typeof JobsDB_Common.GetOmnitureContextDataFromCookie === 'function')
# {
#     var cookieContextDatas = JobsDB_Common.GetOmnitureContextDataFromCookie();
#     for(var key in cookieContextDatas)
#     {
#         if(cookieContextDatas.hasOwnProperty(key)) {
#             s.contextData[key] = cookieContextDatas[key];
#         }
#     }
#     JobsDB_Common.ClearOmnitureContextDataCookie();
# }
# if(typeof abTest === 'function'){var ab = new abTest(s,'[{"SegmentRangeFrom":1,"SegmentRangeTo":10000,"SegmentTestGroupFrom":5001,"SegmentTestGroupTo":10000,"SendLabel":false,"DrawSampleAjaxURL":"/th/en/Home/UpdateProminentPromptTestingGroupValue","CookieExpireMilliseconds":3153600000000.0,"VersionNumber":0,"ABTestKey":"AB.Key","PercentOfB":0.0,"IsDrawFromAjax":true,"UserBaseTestingMethod":false,"OmnitureA":"1","OmnitureB":"2","CookieDomain":null}]');}
# s.eVar1 = "EN";
# s.eVar2 = "home";
# s.eVar6 = "D=g";
# s.eVar10 = "D=s_vi";
# s.prop6 = "D=v6";
# s.prop10 = "D=v10";
# s.pageName = 'home';
# // P1 registration status
# var P1RegistrationFromHomepageBannerCookie;
# var isEnableP1HomepageBanner = 'False'; // For P1 Homepage Banner
# var isUsingNewP1HomepageBanner = 'True'; // For P1 Homepage Banner
# if(isEnableP1HomepageBanner === "True" || isUsingNewP1HomepageBanner === "True") {
#    P1RegistrationFromHomepageBannerCookie = getCookie('P1RegistrationSuccessFromHomepageBanner');
# }
# var P1RegistrationCookie = getCookie('P1RegistrationSuccess');
# // cases
# if(P1RegistrationCookie === "True" && P1RegistrationFromHomepageBannerCookie === "True") {
#    s.contextData['JobSeeker.Registration'] = 'Homepage Top Banner';
#    $.cookie('P1RegistrationSuccess', null, { path: '/' });
#    $.cookie('P1RegistrationSuccessFromHomepageBanner', null, { path: '/' });
# }
# else if(P1RegistrationCookie === "True") {
#    s.contextData['JobSeeker.Registration'] = 'Registration';
#    $.cookie('P1RegistrationSuccess', null, { path: '/' });
# }
# if(s.eVar31) {s.eVar31 += isPerformanceAd;}
# if(typeof JobsDB_System_Messaging != 'undefined') { JobsDB_System_Messaging.PublishEvent('JobAdSourceReady',''); }
# //User classification
# var uc_uid; var isHasResumeId; var isHasP1Profile; var userClassificationCookie;
# var visitNumber = s.getVisitNum();
# var languageCodeID = getLanguageID(s.eVar1);
# var loginStatusID = getLoginStatusID(s.eVar4);
# if(loginStatusID == 0 || loginStatusID == 3) {
#    isHasResumeId = 0;
#    isHasP1Profile = 2;
# }else {
#    userClassificationCookie = getCookie('UserClassification');
#    if(userClassificationCookie == null) {
#        ajaxSynchronization("https://th.jobsdb.com/TH/en/JobSeeker/UpdateUserClassificationCookie", false, false, "GET");
#        userClassificationCookie = getCookie('UserClassification');
#    }
#    var cookieObj = JSON.parse(userClassificationCookie);
#    uc_uid = cookieObj.Uid;
#    if(uc_uid != s.eVar3){
#        document.cookie='UserClassification=; expires=Thu, 01 Jan 1970 00:00:01 GMT; path=/';
#        ajaxSynchronization("https://th.jobsdb.com/TH/en/JobSeeker/UpdateUserClassificationCookie", false, false, "GET");
#        userClassificationCookie = getCookie('UserClassification');
#        cookieObj = JSON.parse(userClassificationCookie);
#    }
#    isHasResumeId = cookieObj.IsHasResume;
#    isHasP1Profile = cookieObj.IsHasP1Profile;
# }
# var zoomRatio = 0;
# if(window.parent.detectZoom != undefined) {
#    zoomRatio = Math.round(window.parent.detectZoom.zoom()*1000)/10;
# }
# s.eVar51 = visitNumber + ":" + languageCodeID + ":" + loginStatusID + ":" + isHasResumeId + ":" + zoomRatio + ":" + isHasP1Profile +":0:0:0:0";
# var abSsrpGroupCookie = getCookie('ABSSRPGroup');
# if(abSsrpGroupCookie === "A" || abSsrpGroupCookie === "B") {
#    s.contextData['AB.SuperchargeSRP'] = abSsrpGroupCookie;
# }
#
#
# var abPersonalizedHomepagepCookie = getCookie('showNewHomePage');
# if(abPersonalizedHomepagepCookie) {
#     s.contextData['ABDiscover.PersonalizedHomepage'] = abPersonalizedHomepagepCookie;
# }
#
# var abHPGroupCookie = getCookie('ABHPGroup');
# if(abHPGroupCookie === "A" || abHPGroupCookie === "B") {
#     s.contextData['AB.HPGroup'] = abHPGroupCookie;
# }
#
# var abJDGroupCookie = getCookie('ABJDGroup');
# if(abJDGroupCookie === "A" || abJDGroupCookie === "B") {
#     s.contextData['AB.JobAdGroup'] = abJDGroupCookie;
# }
# var userInfo = getCookie('JsAccInfo_XX');
#
# try{
# var flag = true; var uid;
# var encryptedJsId = getQueryString('jsID');
# var lastLoginCookie = getCookie('JsLoginTime');
# if(JobsDB_System_Validator.CheckIsLogined(false) && flag)  {
#    var useInfoObj = (userInfo) ? eval('(' + userInfo + ')') : null;
#
#    var userid = (useInfoObj) ? useInfoObj.Uid : null;
#
#    if(userid != null)  {
#
#        if(useInfoObj.Usage == 'P') {
#
#           s.contextData['Login.Status'] ='Partial Logged In';
#            } else {
#           s.contextData['Login.Status'] ='Logged In';
#            }
#        if(lastLoginCookie != null) {
#            var cookieObj = JSON.parse(lastLoginCookie);
#            euid = cookieObj.Euid;
#            s.contextData['Candidate.EncryptedID'] = euid ;
#            }
#    }
# } else {
#        if(lastLoginCookie != null) {
#             var cookieObj = JSON.parse(lastLoginCookie);
#             euid = cookieObj.Euid;
#           s.contextData['Candidate.EncryptedID'] = euid ;
#           s.contextData['Login.Status'] ='Member Logged out';
#        } else if (encryptedJsId != '' && encryptedJsId != null )   {
#           s.contextData['Candidate.EncryptedID'] = encryptedJsId;
#           s.contextData['Login.Status'] ='Member Logged out';
#        }   else    {
#           s.contextData['Login.Status'] ='Logged Out';
#        }
#  }
#          function getQueryString( field ) {
#              var href = window.location.href;
#              var reg = new RegExp( '[?&]' + field + '=([^&#]*)', 'i' );
#              var stringVal = reg.exec(href);
#              return stringVal ? stringVal[1] : '';
#          };
#  }
# catch(e){ }
# if(typeof ModifyEventJsVal === 'undefined' || ModifyEventJsVal == null){s.events="event42";
# }else{s.events = ModifyEventJsVal;}
# if(typeof JobsDB_OmnitureSiteCatalystPageDataFilter === 'function')
#  {
# JobsDB_OmnitureSiteCatalystPageDataFilter(s);
#  }
#
# if(typeof AjaxPageName !== 'undefined'){ s.pageName = AjaxPageName; if(typeof OverrideEvar2 !== 'undefined' && OverrideEvar2){s.eVar2 = AjaxPageName; s.prop6 = AjaxPageName;} }
# if(typeof OmnitureNotSentToServer === 'undefined' || OmnitureNotSentToServer){var s_code=s.t();if(s_code)document.write(s_code);}
# if(typeof InitGoogleTagManager === 'function') { InitGoogleTagManager(); }
# }
# if(window.parent && window.parent != window && window.parent.suppressChildOmnitureCodesPageName != undefined){
# suppressOmnitureCodes = (window.parent.suppressChildOmnitureCodesPageName == 'home');
# }
# if (typeof suppressOmnitureCodes == 'undefined' || suppressOmnitureCodes == null || (!suppressOmnitureCodes) ){
# var sObject = s;
# var sContextDataObj;
# try{sContextDataObj = s_contextData}catch(e){}
# if(typeof jQuery != 'undefined'){ $(document).ready(function() {InitOmnitureSiteCatalyst(sObject,sContextDataObj);}); }
# else{ window.onload = function (){
#  $(document).ready(function() {
#  InitOmnitureSiteCatalyst(sObject,sContextDataObj);
# } ) }
# }
# if(typeof JobsDB_Common != 'undefined')
# {
#  JobsDB_Common.ClearPageTrackOmnitureCarry();
# }
# }
# //]]>
#   </script>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-QT33" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    ga_account='UA-2012489-14';
#
# function InitGoogleTagManager(){(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-QT33');
# }
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Google Code for Remarketing Tag -->
#   <!--------------------------------------------------
# Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories.
# See more information and instructions on how to setup the tag on: http://google.com/ads/remarketingsetup
# --------------------------------------------------->
#   <style type="text/css">
#    iframe[name='google_conversion_frame']{ display: none; }
#   </style>
#   <script type="text/javascript">
#    /* <![CDATA[ */
#     var google_conversion_id = 944810267;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/944810267/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <!-- Google Code for Remarketing Tag -->
#   <!--------------------------------------------------
# Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories.
# See more information and instructions on how to setup the tag on: http://google.com/ads/remarketingsetup
# --------------------------------------------------->
#   <style type="text/css">
#    iframe[name='google_conversion_frame']{ display: none; }
#   </style>
#   <script type="text/javascript">
#    /* <![CDATA[ */
#     var google_conversion_id = 963207106;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/963207106/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <!-- Google Double Click -->
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
# google_ad_client: 'ca-pub-9263924777316633',
# enable_page_level_ads: true
# });
#   </script>
#   <!-- End Google Double Click -->
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore  || [];_comscore.push({c1:'2',c2:'13911996'});( function(){ var s = document.createElement('script'), el = document.getElementsByTagName('script')[0]; s.async = true; s.src = (document.location.protocol == 'https:' ? 'https://sb' : 'http://b') + '.scorecardresearch.com/beacon.js'; el.parentNode.insertBefore(s, el);} )();
#   </script>
#   <noscript>
#    <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=13911996&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- End comScore Tag -->
#   <script type="text/javascript">
#    var flag = true;
# function LoginTrack() {
# var uid; var expiredTime; var euid; var decryptionLink; var link; var updatedLink;
# var encryptedJsId = getQueryString('jsID');
# var lastLoginCookie = getCookie('JsLoginTime');
# if(JobsDB_System_Validator.CheckIsLogined(false) && flag) {
#      if(lastLoginCookie == null) {
#          ajaxSynchronization("https://th.jobsdb.com/TH/en/JobSeeker/LoginTrack?src=1&encryptedJsId=0", true, false, "GET");
#      }
#      else {
#          var cookieObj = JSON.parse(lastLoginCookie);
#          uid = cookieObj.Uid;
#          expiredTime = cookieObj.Time;
#          var isTodayCookie = (new Date(expiredTime).getDate() == new Date().getUTCDate());
#          if(uid != JobsDB_System_Authentication.GetJobSeekerIdAndTicket().Id || !isTodayCookie) {
#              ajaxSynchronization("https://th.jobsdb.com/TH/en/JobSeeker/LoginTrack?src=1&encryptedJsId=0", true, false, "GET");
#          }
#      }
# }
# else{
#          if (encryptedJsId == '' || encryptedJsId == null ){
#              if (lastLoginCookie != null)
#                 {
#                   var cookieObj = JSON.parse(lastLoginCookie);
#                   uid = cookieObj.Uid;
#                   expiredTime = cookieObj.Time;
#                   euid = cookieObj.Euid;
#                   var isTodayCookie = (new Date(expiredTime).getDate() == new Date().getUTCDate());
#                   if(uid!=null && !isTodayCookie)
#                   {
#                      link = "https://th.jobsdb.com/TH/en/JobSeeker/LoginTrack?src=1&encryptedJsId=0";
#                      updatedLink = link.replace('0', euid);
#                      ajaxSynchronization(updatedLink, true, false, "GET");
#                   }
#                 }
#          }else{
#                  if (lastLoginCookie == null) {
#                      link = "https://th.jobsdb.com/TH/en/JobSeeker/LoginTrack?src=1&encryptedJsId=0";
#                      updatedLink = link.replace('0', encryptedJsId);
#                      ajaxSynchronization(updatedLink, true, false, "GET");
#                     }
#                  else{
#              	    var cookieObj = JSON.parse(lastLoginCookie);
#                      euid = cookieObj.Euid;
#                      expiredTime = cookieObj.Time;
#                      var isTodayCookie = (new Date(expiredTime).getDate() == new Date().getUTCDate());
#                       if(euid!=encryptedJsId || !isTodayCookie) {
#                          link = "https://th.jobsdb.com/TH/en/JobSeeker/LoginTrack?src=1&encryptedJsId=0";
#                          updatedLink = link.replace('0', encryptedJsId);
#                          ajaxSynchronization(updatedLink, true, false, "GET");
#                      }
#                  }
#          }
# }
# }
# if(typeof JobsDB_System_Validator != 'undefined'){
# LoginTrack();
# if(typeof JobsDB_System_Messaging != 'undefined'){
# JobsDB_System_Messaging.RegisterToListenEvent('LocalRefreshAuthenticationTicket', function() { if(flag) { LoginTrack(); } flag = false; });
# }
# }
#          function getQueryString( field ) {
#              var href = window.location.href;
#              var reg = new RegExp( '[?&]' + field + '=([^&#]*)', 'i' );
#              var stringVal = reg.exec(href);
#              return stringVal ? decodeURIComponent(stringVal[1]) : '';
#          };
#   </script>
#   <script type="application/ld+json">
#    {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "legalName": "jobsDB Thailand",
#   "name": "jobsDB Thailand",
#   "description": "jobsDB.com is a leading job portal with substantial positions across Hong Kong, Indonesia, Singapore and Thailand, we are Asia's preferred destination for candidates. With a team of 1,000 talented individuals, we've a strong local presence in every country we're in.",
#   "url": "https://th.jobsdb.com/th",
#   "logo": "https://th.content.jobsdbcdn.com/Content/v381/Images/shared/og_image_600x600.png",
#   "contactPoint": [
#     {
#       "@type": "ContactPoint",
#       "telephone": "+66 2 667 0700",
#       "contactType": "customer service"
#     },
#     {
#       "@type": "ContactPoint",
#       "telephone": "+66 2 667 0797",
#       "contactType": "customer service"
#     },
#     {
#       "@type": "ContactPoint",
#       "telephone": "+66 2 667 0824",
#       "contactType": "customer service"
#     }
#   ],
#   "sameAs": [
#     "https://plus.google.com/109178512494210043142/posts",
#     "https://www.facebook.com/JobsDBThailandFan",
#     "https://twitter.com/jobsdbth"
#   ]
# }
#   </script>
#  </body>
# </html>

# %%
html_list = soup.find_all('a',class_="clearfix")
x = html_list[0].prettify()
print(re.search("job-list/(.*?)/(.*?)/",x))
# Out:
# <re.Match object; span=(30, 56), match='job-list/accounting/audit/'>

# %%
html_list[0].prettify()
# Out:
# '<a class="clearfix" href="/th/job-list/accounting/audit/1?JSSRC=HPJC" title="Audit">\n <span class="namewrap clearfix">\n  <span>\n   Audit\n  </span>\n </span>\n</a>\n'

# %%
x[30:56]
# Out:
# 'job-list/accounting/audit/'

# %%
#For regular expression testing
# p = re.compile("job-list/(.*?)/(.*?)/")
# p.findall(x)

# %%
p = re.compile("job-list/(.*?)/(.*?)/")
job_category_df = pd.DataFrame(columns = ['job_category','job_subcategory'])
for i,html in enumerate(html_list):
    print(p.findall(html.prettify()))
    job = p.findall(html.prettify())
    if job == []:
        break
    job_category_df.loc[i] = [job[0][0],job[0][1]]
# Out:
# [('accounting', 'audit')]
# [('accounting', 'credit-control')]
# [('accounting', 'general-accounting')]
# [('accounting', 'taxation')]
# [('accounting', 'others')]
# [('admin-hr', 'administration-operation-clerical-support')]
# [('admin-hr', 'compensation-benefits')]
# [('admin-hr', 'employee-relations')]
# [('admin-hr', 'recruitment-executive-search')]
# [('admin-hr', 'secretary-personal-assistant')]
# [('admin-hr', 'training-development')]
# [('admin-hr', 'others')]
# [('banking-finance', 'analysis')]
# [('banking-finance', 'asset-management')]
# [('banking-finance', 'bancassurance')]
# [('banking-finance', 'corporate-banking')]
# [('banking-finance', 'corporate-finance')]
# [('banking-finance', 'credit-analysis-approval')]
# [('banking-finance', 'credit-management')]
# [('banking-finance', 'equities-capital-markets')]
# [('banking-finance', 'financial-services')]
# [('banking-finance', 'fund-management')]
# [('banking-finance', 'investment')]
# [('banking-finance', 'loan')]
# [('banking-finance', 'mortgage')]
# [('banking-finance', 'private-banking')]
# [('banking-finance', 'retail-banking')]
# [('banking-finance', 'risk-management')]
# [('banking-finance', 'treasury')]
# [('banking-finance', 'wealth-management')]
# [('banking-finance', 'others')]
# [('beauty-care-health', 'spa-therapist-fitness-sports-recreation')]
# [('beauty-care-health', 'others')]
# [('building-construction', 'architectural-services')]
# [('building-construction', 'building-construction-qs')]
# [('building-construction', 'civil-structural')]
# [('design', 'fashion')]
# [('design', 'graphics')]
# [('design', 'industrial-product')]
# [('design', 'interior')]
# [('design', 'multi-media')]
# [('design', 'visual-merchandising')]
# [('design', 'web-design')]
# [('design', 'others')]
# [('education', 'lecturer-professor')]
# [('education', 'teacher')]
# [('education', 'tutor-instructor')]
# [('education', 'others')]
# [('engineering', 'chemical')]
# [('engineering', 'electrical-electronics')]
# [('engineering', 'energy-natural-resources')]
# [('engineering', 'engineering-project-management')]
# [('engineering', 'health-safety-environmental')]
# [('engineering', 'industrial')]
# [('engineering', 'maintenance')]
# [('engineering', 'manufacturing-production')]
# [('engineering', 'mechanical')]
# [('engineering', 'telecommunication-wireless-radio')]
# [('engineering', 'others')]
# [('hospitality-foodbeverage', 'foodbeverage')]
# [('hospitality-foodbeverage', 'management')]
# [('hospitality-foodbeverage', 'operation')]
# [('hospitality-foodbeverage', 'tourism-travel-agency')]
# [('hospitality-foodbeverage', 'others')]
# [('information-technology', 'application-specialist-network')]
# [('information-technology', 'application-specialist-software')]
# [('information-technology', 'data-scientist')]
# [('information-technology', 'dba')]
# [('information-technology', 'hardware')]
# [('information-technology', 'internet-seo')]
# [('information-technology', 'it-auditing')]
# [('information-technology', 'it-consulting')]
# [('information-technology', 'it-project-management-team-lead')]
# [('information-technology', 'mis')]
# [('information-technology', 'mobile-wireless-communications')]
# [('information-technology', 'network-system')]
# [('information-technology', 'programming-software-development')]
# [('information-technology', 'security')]
# [('information-technology', 'support')]
# [('information-technology', 'testing-qa')]
# [('information-technology', 'ui-ux-designer')]
# [('information-technology', 'others')]
# [('insurance', 'actuarial')]
# [('insurance', 'claims-officer')]
# [('insurance', 'insurance-agent-broker')]
# [('insurance', 'underwriter')]
# [('insurance', 'others')]
# [('management', 'general-management')]
# [('management', 'management-trainee')]
# [('management', 'top-executives')]
# [('manufacturing', 'garment-textile')]
# [('manufacturing', 'gems-jewelry')]
# [('manufacturing', 'general-production')]
# [('manufacturing', 'manufacturing-management')]
# [('manufacturing', 'printing')]
# [('manufacturing', 'product-development-management')]
# [('manufacturing', 'production-planning-control')]
# [('manufacturing', 'quality-assurance-control-testing-iso')]
# [('manufacturing', 'others')]
# [('marketing-public-relations', 'brand-product-management')]
# [('marketing-public-relations', 'copy-writing')]
# [('marketing-public-relations', 'digital-marketing')]
# [('marketing-public-relations', 'direct-marketing')]
# [('marketing-public-relations', 'event-marketing')]
# [('marketing-public-relations', 'management')]
# [('marketing-public-relations', 'market-research')]
# [('marketing-public-relations', 'marketing-communication')]
# [('marketing-public-relations', 'marketing-general')]
# [('marketing-public-relations', 'pr-general')]
# [('marketing-public-relations', 'others')]
# [('media-advertising', 'broadcasting-tv-radio')]
# [('media-advertising', 'creative-design')]
# [('media-advertising', 'editorial-journalism')]
# [('media-advertising', 'photography-video')]
# [('media-advertising', 'print-media')]
# [('media-advertising', 'production')]
# [('media-advertising', 'strategic-planning')]
# [('media-advertising', 'others')]
# [('medical-services', 'doctor-practitioner-surgeon')]
# [('medical-services', 'medical-services-technician')]
# [('medical-services', 'nursing')]
# [('medical-services', 'pharmaceutical')]
# [('medical-services', 'specialist')]
# [('medical-services', 'veterinarian')]
# [('medical-services', 'others')]
# [('merchandising-purchasing', 'garment')]
# [('merchandising-purchasing', 'household')]
# [('merchandising-purchasing', 'industrial')]
# [('merchandising-purchasing', 'merchandising-others')]
# [('merchandising-purchasing', 'procurement-purchasing-sourcing')]
# [('professional-services', 'business-analysis-data-analysis')]
# [('professional-services', 'business-consultancy')]
# [('professional-services', 'legal-compliance')]
# [('professional-services', 'translation')]
# [('property', 'property-consultancy')]
# [('property', 'property-management')]
# [('property', 'others')]
# [('public-civil', 'civil-services')]
# [('public-civil', 'military-defense')]
# [('public-civil', 'social-services-non-profit-organization')]
# [('sales-cs-business-devpt', 'account-servicing')]
# [('sales-cs-business-devpt', 'business-development')]
# [('sales-cs-business-devpt', 'call-centre')]
# [('sales-cs-business-devpt', 'channel-distribution')]
# [('sales-cs-business-devpt', 'customer-service')]
# [('sales-cs-business-devpt', 'direct')]
# [('sales-cs-business-devpt', 'retail-sales')]
# [('sales-cs-business-devpt', 'sales-administration')]
# [('sales-cs-business-devpt', 'sales-management')]
# [('sales-cs-business-devpt', 'technical-sales-sales-engineer')]
# [('sales-cs-business-devpt', 'tele-sales')]
# [('sales-cs-business-devpt', 'wholesale')]
# [('sales-cs-business-devpt', 'others')]
# [('sciences-lab-researchdevelopment', 'biotechnology')]
# [('sciences-lab-researchdevelopment', 'chemical')]
# [('sciences-lab-researchdevelopment', 'energy-natural-resources-oil-gas')]
# [('sciences-lab-researchdevelopment', 'environmental-science-waste-management')]
# [('sciences-lab-researchdevelopment', 'food-science')]
# [('sciences-lab-researchdevelopment', 'laboratory')]
# [('sciences-lab-researchdevelopment', 'life-science')]
# [('sciences-lab-researchdevelopment', 'research-development')]
# [('telecomm', 'gsm-engineering')]
# [('telecomm', 'network-administration')]
# [('telecomm', 'o-m-engineering')]
# [('telecomm', 'rf-planning-installation-administration')]
# [('telecomm', 'system-administration')]
# [('telecomm', 'system-engineering')]
# [('telecomm', 'systems-security')]
# [('telecomm', 'telecommunications-technical-support')]
# [('telecomm', 'others')]
# [('transportation-logistics', 'airline')]
# [('transportation-logistics', 'automotive')]
# [('transportation-logistics', 'aviation-services')]
# [('transportation-logistics', 'export-import')]
# [('transportation-logistics', 'freight-forwarding')]
# [('transportation-logistics', 'inventory-warehousing')]
# [('transportation-logistics', 'shipping')]
# [('transportation-logistics', 'supply-chain')]
# [('transportation-logistics', 'others')]
# [('others', 'agriculture-forestry-fishing')]
# [('others', 'skill-worker')]
# [('others', 'student-fresh-graduate-no-experience')]
# [('others', 'technician')]
# [('others', 'trading')]
# [('others', 'others')]
# []

# %%
job_category_df.head(10)
# Out:
#   job_category                            job_subcategory
# 0   accounting                                      audit
# 1   accounting                             credit-control
# 2   accounting                         general-accounting
# 3   accounting                                   taxation
# 4   accounting                                     others
# 5     admin-hr  administration-operation-clerical-support
# 6     admin-hr                      compensation-benefits
# 7     admin-hr                         employee-relations
# 8     admin-hr               recruitment-executive-search
# 9     admin-hr               secretary-personal-assistant

# %% [markdown]
# # Get Salary

# %%
# # For test html
# test_html = html_list[0].prettify()
# p = re.compile('href="/(.*?)\?')
# p.findall(test_html)[0]

# %%
# # get the first page of all job post of all job categories
# url_list =[]
# for html in html_list:
#     url = 'https://th.jobsdb.com/'
#     link = str(p.findall(html.prettify())[0])
# #     if 'job-list' not in link:
# #         break
#     url_list.append(url+link)
# url_list

# %%
# Accounting --> Audit page 1 Link for branded
source = requests.get('https://th.jobsdb.com/th/job-list/accounting/audit/1').text
soup = BeautifulSoup(source,'html.parser')
soup.find_all('div',class_="result-sherlock-cell branded")[0].find('a',class_ = 'posLink',href=True)['href']
# Out:
# 'https://th.jobsdb.com/th/en/job/accountant-300003002200652'

# %%
# Accounting --> Audit page 1 Link for branded plus
soup.find_all('div',class_="result-sherlock-cell branded plus")[0].find('a',class_ = 'posLink',href=True)['href']
# Out:
# 'https://th.jobsdb.com/th/en/job/internal-control-manager-300003002203716'

# %%
# Get all job links for Accounting --> Audit page 1
job_links = soup.find_all('div',class_="result-sherlock-cell branded")
job_links_plus = soup.find_all('div',class_="result-sherlock-cell branded plus")
all_job_links = job_links_plus + job_links

# %%
#Show some job links for Accounting --> Audit page 1
for job_link in all_job_links[0:5]:
    print(job_link.find('a',class_='posLink',href=True)['href'])
# Out:
# https://th.jobsdb.com/th/en/job/internal-control-manager-300003002203716
# https://th.jobsdb.com/th/en/job/audit-manager-300003002203605
# https://th.jobsdb.com/th/en/job/finance-manager-300003002203583
# https://th.jobsdb.com/th/en/job/senior-ar-officer-300003002203369
# https://th.jobsdb.com/th/en/job/director-of-corporate-accounting-300003002203344

# %%
##Final Scraping
## จิงๆแล้วทำแบบเข้า job category ใหญ่ทีเดียวก้ได้ เช่นแบบ Accounting ทีเดียวพอไม่ต้อง accounting --> audit 
## เพราะว่ามันจะมีพวกลิ้งซ้ำแต่ไว้ทำทีหลังก้ได้มั้ง


jobs_df = pd.DataFrame(columns = ['job_title','job_categories','career_level',
                                  'experience_year','salary','employment_type','job_responsibilities',
                                 'job_qualifications','job_description'])

num_request_without_break = 0  # to prevent too frequent requests
sheet_number = 1  # use to name excel sheet

for url in url_list:  # Iterate over all job categories
    
    ##Get first job page and the last page number
    url = re.sub('[0-9]','',url)
    source = requests.get(url).text
    soup = BeautifulSoup(source,'html.parser')
    last_page_url = soup.find_all('a',class_ = 'pagebox')
    last_page_url = last_page_url[-1]['href'] if last_page_url != [] else None
    max_page = int(re.findall(r'\b\d+\b', last_page_url)[0]) if last_page_url is not None else 0  # last page number

    for page in range(max_page):  # iterate over all page until all page has been reached
        page = page+1
        if page == 1:
            pass
        else:
            url = re.sub('[0-9]','',url)
            url = url + str(page)
            source = requests.get(url).text
            soup = BeautifulSoup(source,'html.parser')  
        job_links = soup.find_all('div',class_="result-sherlock-cell branded")
        job_links_plus = soup.find_all('div',class_="result-sherlock-cell branded plus")
        all_job_links = job_links_plus + job_links
        print(url)    
        
        #request counter (request for a page)
        num_request_without_break += 1
    
        for i,job_link in enumerate(all_job_links):  ## Get all the jobs for each page
            
            # open the job link page
            url_job = job_link.find('a',class_='posLink',href=True)['href']
            source = requests.get(url_job).text
            soup = BeautifulSoup(source,'html.parser')

            # get career level and experience year
            career_level = soup.find('b',class_ = 'primary-meta-lv')
            experience_year = soup.find('b',class_ = 'primary-meta-exp')
            
            career_level = career_level.text if career_level is not None else None
            experience_year = experience_year.text if experience_year is not None else None
            
            # get all job categories 
            job_function_html = soup.find('div',class_="primary-meta-box row meta-jobfunction")
            job_function_html = job_function_html.find('p').find_all('a') if job_function_html is not None else []
            job_categories = []
            for html in job_function_html:
                if 'job-list' in html['href']:
                    job_categories.append(re.compile("job-list/(.*?)/(.*?)/").findall(html.prettify())[0])
            
            
            #Get job responsibilities & qualifications & job description
            job_description = soup.find_all('div',class_="jobad-primary-details")
            job_description = job_description[0].text if job_description != [] else ''
            job_description = job_description.replace("\n","")
            job_description = job_description.replace("\xa0","")
            job_description = job_description.replace("\r","")
            job_responsibilities = re.compile("(.*)Qualification").findall(job_description) #All before Qualification
            job_qualifications = re.compile("Qualification(.*)").findall(job_description) # All after Qualification

                    
            # get job_title,salary,employment type   

            
            job_title = soup.find('h1',class_="general-pos ad-y-auto-txt2")
            job_title = job_title.text if job_title is not None else None
            
            salary = soup.find('div',class_="primary-meta-box row meta-salary")
            salary = salary.find('span').text if salary is not None else None
            
            employment_type = soup.find('div',class_="primary-meta-box row meta-employmenttype")
            employment_type = employment_type.find('p').text if employment_type is not None else None
            
            
            
            jobs_df.loc[len(jobs_df)] = [job_title,job_categories,career_level,
                                         experience_year,salary,employment_type,
                                        job_responsibilities,job_qualifications,
                                        job_description]
            
            #request counter (request for a job)
            num_request_without_break += 1
            
            # sleep and save checkpoint after ~1000 requests 
            if (num_request_without_break > 1000):    
                sheet_name = 'jobs_data'+str(sheet_number)+'.csv'
                jobs_df.to_csv(sheet_name,index = False,encoding = 'utf-8-sig')
                num_request_without_break = 0
                sheet_number += 1
                print('Excel sheet ',sheet_name,' saved')
                print('Sleeping for 30 secs')
                jobs_df = pd.DataFrame(columns = ['job_title','job_categories','career_level',
                                                  'experience_year','salary','employment_type','job_responsibilities',
                                                  'job_qualifications','job_description'])
                time.sleep(30)
            


jobs_df
# Out:
# https://th.jobsdb.com/th/job-list/accounting/audit/
# https://th.jobsdb.com/th/job-list/accounting/audit/2
# https://th.jobsdb.com/th/job-list/accounting/audit/3
# https://th.jobsdb.com/th/job-list/accounting/audit/4
# https://th.jobsdb.com/th/job-list/accounting/audit/5
# https://th.jobsdb.com/th/job-list/accounting/credit-control/
# https://th.jobsdb.com/th/job-list/accounting/credit-control/2
# https://th.jobsdb.com/th/job-list/accounting/credit-control/3
# https://th.jobsdb.com/th/job-list/accounting/credit-control/4
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/2
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/3
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/4
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/5
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/6
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/7
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/8
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/9
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/10
# https://th.jobsdb.com/th/job-list/accounting/general-accounting/11
# From cffi callback <function _verify_callback at 0x0000021F92B58828>:
# Traceback (most recent call last):
#   File "C:\Users\North\Anaconda3\envs\tf2\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\envs\tf2\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~\Anaconda3\envs\tf2\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1670         else:
# -> 1671             _raise_current_error()
#    1672
#
# ~\Anaconda3\envs\tf2\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     490             except OpenSSL.SSL.Error as e:
# --> 491                 raise ssl.SSLError("bad handshake: %r" % e)
#     492             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\tf2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3\envs\tf2\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='th.jobsdb.com', port=443): Max retries exceeded with url: /th/en/job/senior-accountant-ap-%E0%B8%9E%E0%B8%99%E0%B8%B1%E0%B8%81%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%9A%E0%B8%B1%E0%B8%8D%E0%B8%8A%E0%B8%B5%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%AB%E0%B8%99%E0%B8%B5%E0%B9%89%E0%B8%AD%E0%B8%B2%E0%B8%A7%E0%B8%B8%E0%B9%82%E0%B8%AA-300003002201197 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-36-40c92273e90b> in <module>
#      42             # open the job link page
#      43             url_job = job_link.find('a',class_='posLink',href=True)['href']
# ---> 44             source = requests.get(url_job).text
#      45             soup = BeautifulSoup(source,'html.parser')
#      46
#
# ~\Anaconda3\envs\tf2\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\tf2\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\tf2\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\tf2\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\tf2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='th.jobsdb.com', port=443): Max retries exceeded with url: /th/en/job/senior-accountant-ap-%E0%B8%9E%E0%B8%99%E0%B8%B1%E0%B8%81%E0%B8%87%E0%B8%B2%E0%B8%99%E0%B8%9A%E0%B8%B1%E0%B8%8D%E0%B8%8A%E0%B8%B5%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%AB%E0%B8%99%E0%B8%B5%E0%B9%89%E0%B8%AD%E0%B8%B2%E0%B8%A7%E0%B8%B8%E0%B9%82%E0%B8%AA-300003002201197 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %% [markdown]
# # Updated version

# %% [markdown]
# ## Get all URL with last page number

# %%
job_categories_list = job_category_df.job_category.unique().tolist()
url_list = []
for job_category in job_categories_list:
    url = 'https://th.jobsdb.com/th/jobs/'+job_category
    url_list.append(url)

url_list_with_max_page = []

# Iterate over all job category to get their last page
for url in url_list:
    source = requests.get(url).text
    soup = BeautifulSoup(source,'html.parser')
    last_page_url = soup.find_all('a',class_ = 'pagebox')
    last_page_url = last_page_url[-1]['href'] if last_page_url != [] else None
    max_page = int(re.findall(r'\b\d+\b', last_page_url)[0]) if last_page_url is not None else 0  # last page number
    url_list_with_max_page.append((url,max_page))
url_list_with_max_page[0:2]
# Out:
# [('https://th.jobsdb.com/th/jobs/accounting', 22),
#  ('https://th.jobsdb.com/th/jobs/admin-hr', 19)]

# %% [markdown]
# ## Request data

# %%
def get_job_links_in_page(main_url,page):
    request_url = main_url + '/' + str(page)
    source = requests.get(request_url).text
    soup = BeautifulSoup(source,'html.parser')
    job_links = soup.find_all('div',class_="result-sherlock-cell branded")
    job_links_plus = soup.find_all('div',class_="result-sherlock-cell branded plus")
    all_job_links = job_links_plus + job_links
    print(request_url)
    return all_job_links

# %%
request_counter = 0
sheet_number = 23

for main_page in url_list_with_max_page[-2:]:
    last_page = main_page[1]
    main_url = main_page[0]
    for page in range(last_page):
        page = page+1
        all_job_links = get_job_links_in_page(main_url,page)
        
        for i,job_link in enumerate(all_job_links):
            job_url = job_link.find('a',class_='posLink',href=True)['href']
            source = requests.get(job_url).text
            soup = BeautifulSoup(source,'html.parser')

            # get career level and experience year
            career_level = soup.find('b',class_ = 'primary-meta-lv')
            experience_year = soup.find('b',class_ = 'primary-meta-exp')
            
            career_level = career_level.text if career_level is not None else None
            experience_year = experience_year.text if experience_year is not None else None

            # get all job categories 
            job_function_html = soup.find('div',class_="primary-meta-box row meta-jobfunction")
            job_function_html = job_function_html.find('p').find_all('a') if job_function_html is not None else []
            job_categories = []
            for html in job_function_html:
                if 'job-list' in html['href']:
                    job_categories.append(re.compile("job-list/(.*?)/(.*?)/").findall(html.prettify())[0])
            
            
            #Get job responsibilities & qualifications & job description
            job_description = soup.find_all('div',class_="jobad-primary-details")
            job_description = job_description[0].text if job_description != [] else ''
            job_description = job_description.replace("\n","")
            job_description = job_description.replace("\xa0","")
            job_description = job_description.replace("\r","")
            job_responsibilities = re.compile("(.*)Qualification").findall(job_description) #All before Qualification
            job_qualifications = re.compile("Qualification(.*)").findall(job_description) # All after Qualification

                    
            # get job_title,salary,employment type   
            job_title = soup.find('h1',class_="general-pos ad-y-auto-txt2")
            job_title = job_title.text if job_title is not None else None
            
            salary = soup.find('div',class_="primary-meta-box row meta-salary")
            salary = salary.find('span').text if salary is not None else None
            
            employment_type = soup.find('div',class_="primary-meta-box row meta-employmenttype")
            employment_type = employment_type.find('p').text if employment_type is not None else None
            
            
            # save data into dataframe
            jobs_df.loc[len(jobs_df)] = [job_title,job_categories,career_level,
                                         experience_year,salary,employment_type,
                                        job_responsibilities,job_qualifications,
                                        job_description]
            
            #request counter (request for a job)
            request_counter += 1
            # sleep and save checkpoint after ~500 requests 
            if (request_counter % 500 == 0):    
                sheet_name = 'jobs_data'+str(sheet_number)+'.csv'
                jobs_df.to_csv(sheet_name,index = False,encoding = 'utf-8-sig')
                sheet_number += 1
                jobs_df = pd.DataFrame(columns = ['job_title','job_categories','career_level',
                                                  'experience_year','salary','employment_type','job_responsibilities',
                                                  'job_qualifications','job_description'])  # reset dataframe
 
                print('Excel sheet ',sheet_name,' saved')
                print('Sleeping for 60 secs')


                time.sleep(60)
# Out:
# https://th.jobsdb.com/th/jobs/transportation-logistics/1
# https://th.jobsdb.com/th/jobs/transportation-logistics/2
# https://th.jobsdb.com/th/jobs/transportation-logistics/3
# https://th.jobsdb.com/th/jobs/transportation-logistics/4
# https://th.jobsdb.com/th/jobs/transportation-logistics/5
# https://th.jobsdb.com/th/jobs/transportation-logistics/6
# https://th.jobsdb.com/th/jobs/transportation-logistics/7
# https://th.jobsdb.com/th/jobs/transportation-logistics/8
# https://th.jobsdb.com/th/jobs/transportation-logistics/9
# https://th.jobsdb.com/th/jobs/transportation-logistics/10
# https://th.jobsdb.com/th/jobs/others/1
# https://th.jobsdb.com/th/jobs/others/2
# https://th.jobsdb.com/th/jobs/others/3
# https://th.jobsdb.com/th/jobs/others/4
# Excel sheet  jobs_data23.csv  saved
# Sleeping for 60 secs
# https://th.jobsdb.com/th/jobs/others/5
# https://th.jobsdb.com/th/jobs/others/6
# https://th.jobsdb.com/th/jobs/others/7
# https://th.jobsdb.com/th/jobs/others/8
# https://th.jobsdb.com/th/jobs/others/9
# https://th.jobsdb.com/th/jobs/others/10
# https://th.jobsdb.com/th/jobs/others/11

# %%
#Note : ต้องทำ inner join 22 กับ 23 เพราะมีrequest error จิงๆไม่ต้องก้ได้ ่oin แล้วก้ remove duplicate 5555

# %%
url_list_with_max_page[-1:]
# Out:
# [('https://th.jobsdb.com/th/jobs/others', 11)]

# %% [markdown]
# # Import data

# %%
import pandas as pd
import glob

path = r'C:\Users\North\my_app_folder\Data Scraping' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df_all = pd.concat(li, axis=0, ignore_index=True)
df_all.salary.value_counts()
# Out:
#            Salary provided                                                              6931
#            Salary negotiable                                                            3345
# Salary provided                                                                          266
# Salary negotiable                                                                        226
#            Base salary + high commission                                                 144
#                                                                                         ...
# THB45,000 - 55,000 /month                                                                  1
#            THB16,000 - 35,000 /month (negotiable)                                          1
#            THB10,000 - 16,000 /month (includes high commission)                            1
# THB70,000 - 90,000 /month                                                                  1
#            THB13,000 - 25,000 /month (negotiable)                                          1
# Name: salary, Length: 137, dtype: int64

# %%
len(df_all)
# Out:
# 12504

# %%
df_all.head()
# Out:
#                                            job_title  \
# 0           HR Payroll Administrative(Junior Leve...
# 1           Customer Service & Administrative Off...
# 2           Social Auditor - HR / Compensation & ...
# 3           Senior Administrative & Secretary Exe...
# 4           HSE Auditor - ประสบการณ์ 5 ปี/ผู้ตรวจ...
#
#                                       job_categories  \
# 0  [('admin-hr', 'administration-operation-cleric...
# 1  [('admin-hr', 'administration-operation-cleric...
# 2  [('admin-hr', 'compensation-benefits'), ('admi...
# 3  [('accounting', 'others'), ('admin-hr', 'admin...
# 4  [('engineering', 'health-safety-environmental'...
#
#                           career_level  \
# 0               Entry Level
# 1               Entry Level
# 2              Middle level
# 3              Middle level
# 4               Entry Level
#
#                              experience_year  \
# 0               1 year experience
# 1                                        NaN
# 2              5 years experience
# 3              5 years experience
# 4              5 years experience
#
#                                               salary  \
# 0             Salary provided
# 1             Salary provided
# 2             Salary provided
# 3             Salary provided
# 4             Salary provided
#
#                            employment_type  \
# 0            Full Time, Permanent
# 1            Full Time, Permanent
# 2            Full Time, Permanent
# 3            Full Time, Permanent
# 4            Full Time, Permanent
#
#                                 job_responsibilities  \
# 0                                                 []
# 1  ['Job DescriptionGiving information to clients...
# 2                                                 []
# 3  [' ResponsibilitiesTo assist Director in all a...
# 4                                                 []
#
#                                   job_qualifications  \
# 0                                                 []
# 1  ['s:Bachelor’s degree in relevant discipline.0...
# 2                                                 []
# 3  ['sBachelor’s degree or higher in Accounting, ...
# 4                                                 []
#
#                                      job_description
# 0  Key Responsibilities include:To carry out all ...
# 1  Job DescriptionGiving information to clients (...
# 2  JOB DUTIES:The following job duties are genera...
# 3   ResponsibilitiesTo assist Director in all adm...
# 4  SPECIFIC RESPONSIBILITIES:Acting as the audit ...

# %%
df_all = df_all.drop_duplicates(subset =['job_title','job_categories','career_level','experience_year'])

# %%
df_all = df_all.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df_all[ (df_all['salary']!= 'Salary provided') & (df_all['salary']!= 'Salary negotiable')]
# Out:
#                                                job_title  \
# 17     HR Management & Development Officer - MRT Petc...
# 18     Student Services Coordinator /เจ้าหน้าที่ฝ่ายป...
# 26                      Sales Coordinator (BTS Bangchak)
# 33     HR Generalist  (Assistant Manager) - Retail Fu...
# 41                        C&B Manager - 120K up (Rayong)
# ...                                                  ...
# 12451            Cloud Solution Consultant (Sales Cloud)
# 12452     Programmer (25K-40K) @Samutprakarn (SDG-28740)
# 12461                                                NaN
# 12467  SAP (All Modules) Consultant to Senior Level/ ...
# 12484                         System Analyst (Java/.Net)
#
#                                           job_categories  career_level  \
# 17     [('admin-hr', 'compensation-benefits'), ('admi...  Middle level
# 18     [('admin-hr', 'administration-operation-cleric...   Entry Level
# 26     [('admin-hr', 'administration-operation-cleric...   Entry Level
# 33     [('admin-hr', 'administration-operation-cleric...  Middle level
# 41     [('admin-hr', 'compensation-benefits'), ('admi...     Top level
# ...                                                  ...           ...
# 12451  [('information-technology', 'it-consulting'), ...   Entry Level
# 12452  [('information-technology', 'application-speci...   Entry Level
# 12461  [('information-technology', 'application-speci...     Full Time
# 12467  [('information-technology', 'application-speci...  Senior level
# 12484  [('information-technology', 'application-speci...  Senior level
#
#           experience_year                                   salary  \
# 17                    NaN                THB25,000 - 35,000 /month
# 18     3 years experience   THB20,000 - 30,000 /month (negotiable)
# 26                    NaN                THB16,000 - 20,000 /month
# 33                    NaN                THB45,000 - 70,000 /month
# 41     7 years experience  THB90,000 - 120,000 /month (negotiable)
# ...                   ...                                      ...
# 12451                 NaN   THB25,000 - 45,000 /month (negotiable)
# 12452  2 years experience                THB25,000 - 45,000 /month
# 12461                 NaN                THB45,000 - 55,000 /month
# 12467  5 years experience                  Above THB120,000 /month
# 12484  6 years experience                THB55,000 - 90,000 /month
#
#             employment_type  \
# 17                Permanent
# 18                Full Time
# 26                Permanent
# 33                Permanent
# 41     Full Time, Permanent
# ...                     ...
# 12451  Full Time, Permanent
# 12452  Full Time, Permanent
# 12461             Full Time
# 12467             Full Time
# 12484  Full Time, Permanent
#
#                                     job_responsibilities  \
# 17     ['Location: MRT Petchaburi, BangkokSalary: 25,...
# 18                                                    []
# 26     ['Location: BTS BangchakSalary: 15,000 - 20,00...
# 33     [" Responsibilities:Supporting the recruitment...
# 41                                                  ['']
# ...                                                  ...
# 12451                                                 []
# 12452                                                 []
# 12461  [' Location:Bangkok, Close to BTS/MRTSalary:Up...
# 12467  ['Position:SAP (All Modules) Consultant to Sen...
# 12484                                               ['']
#
#                                       job_qualifications  \
# 17     ["s:Bachelor's Degree in related fields. Male ...
# 18                                                    []
# 26     ["s:Female. Thai nationality. Bachelor's Degre...
# 33     ["s:Male or female. Thai nationality only. Age...
# 41     ['Thai nationality, University degree in Human...
# ...                                                  ...
# 12451                                                 []
# 12452                                                 []
# 12461  ['s:Graduated Bachelor’s Degree in Computer Sc...
# 12467  ['s:Thai national, age between 30 - 43 years.M...
# 12484  ['s:Thai NationalityBachelor’s Degree or highe...
#
#                                          job_description
# 17     Location: MRT Petchaburi, BangkokSalary: 25,00...
# 18     Westminster International / WIN EducationDo yo...
# 26     Location: BTS BangchakSalary: 15,000 - 20,000 ...
# 33     Responsibilities:Supporting the recruitment an...
# 41     QualificationThai nationality, University degr...
# ...                                                  ...
# 12451  Responsibilities:Maintaining and Establishing ...
# 12452  <Job Responsibilities>To Analyze and solve pro...
# 12461  Location:Bangkok, Close to BTS/MRTSalary:Up to...
# 12467  Position:SAP (All Modules) Consultant to Senio...
# 12484  Qualifications:Thai NationalityBachelor’s Degr...
#
# [1085 rows x 9 columns]

# %% [markdown]
# # Maybe try Selenium ?

# %%
jobs_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a38059e77e33> in <module>
# ----> 1 jobs_df
#
# NameError: name 'jobs_df' is not defined
